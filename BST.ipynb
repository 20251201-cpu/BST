# %% [markdown]
# 1-1. 이 이진 검색 트리의 리프 노드는 총 몇개인가?
# ![스크린샷_19-4-2026_225939_.jpeg](data:image/jpeg;base64,...)
#
# ```
# 3개
# ```

# %% [markdown]
# 1-2. 현재 높이 4를 유지하면서 키를 추가한다면 가능한 리프 노드의 최대 개수는 몇개인가?
#
# ```
# 8개
# ```

# %% [markdown]
# 1-3. 높이 4인 이진 검색 트리가 포화 이진 트리 모양이 되면 리프 노드와 리프 노드를
# 제외한 나머지 노드(내부 노드라 한다)의 수는 몇 개나 차이가 나는가?
#
# ```
# 8-7 = 1개
# ```

# %% [markdown]
# 1-4. 위 1-3의 성질은 높이가 ℎ인 모든 포화 이진 트리에 대해 성립하는가?
#
# ```
# 성립한다
# ```

# %% [markdown]
# 2-1. 트리의 총 노드 수가 n이면 리프 노드의 수는 몇 개인가?
#
# ```
# (n+1)/2
# ```

# %% [markdown]
# 2-2. 위 2-1에서 리프 노드의 수와 내부 노드의 수는 어떤 관계인가?
#
# ```
# 리프 노드의 수 = 내부 노드의 수 + 1
# ```

# %% [markdown]
# 3-1. 이 검색 트리를 전위 순회 방식으로 순회할 때 노드의 방문 순서를 나열하시오.
# 순서는 노드에 있는 킷값으로 적으시오.
#
# ![스크린샷_19-4-2026_2308_.jpeg](data:image/jpeg;base64,...)
#
# ```
# 5-3-1-8-7-6-9
# ```

# %% [markdown]
# 3-2. 이 검색 트리를 중위 순회 방식으로 순회할 때 노드의 방문 순서를 나열하시오.
#
# ```
# 1-3-5-6-7-8-9
# ```

# %% [markdown]
# 3-3. 이 검색 트리를 후위 순회 방식으로 순회할 때 노드의 방문 순서를 나열하시오.
#
# ```
# 1-3-6-7-9-8-5
# ```

# %% [markdown]
# 3-4. 중위 순회는 모든 이진 검색 트리에 대해 항상 키를 정렬된 순서로 방문한다는
# 사실을 증명하시오.
#
# ```
# 귀납적 가정: k< h인 모든 k에 대해 성립한다 가정한다.
# 귀납적 전개: (정리가 k= h에 대해 성립함을 보인다)
# 이진 검색 트리 T는 아래와 같이 그릴 수 있다. 귀납적 가정에 의해 중위 순회는 TL과TR을 각각 정렬된 순서로 방문한다. TL의 모든 키는r의 키보다 작고, TR의 모든 키는r의 키보다 크므로,
# 중위 순회 TL→ r → TR는 정렬된 순서다.
# ```
# ![스크린샷_19-4-2026_22443_.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 4. 다음 이진 검색 트리에서 키 30을 검색하는과정을 순서대로 설명하시오.![KakaoTalk_20260419_221421034.jpg](data:image/jpeg;base64,...)
#
# ```
# 1) 루트 로드 방문 (55)
# 30과 55를 비교하면 30<55 이므로, 오른쪽 자식 노드로 이동한다.
# 2) 노드 15 방문
# 30과 15를 비교하면 30>15 이므로, 오른쪽 자식 노드로 이동한다.
# 3) 노드 28 방문
# 30과 28을 비교하면 30>28 이므로, 오른쪽 자식 노드로 이동한다.
# 찾으려는 값 30과 현재 노드 30이 일치하므로 검색 종료.
# ```

# %% [markdown]
# 5. 4번 문제에 이진 검색 트리에서 키 16이 삽입된 후의 모양을 그리시오.
#
# ![KakaoTalk_20260419_221159443.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 6. 다음 이진 검색 트리에서 키 38을 삭제한 후의 모양을 그리시오.
# ![KakaoTalk_20260419_222157344.jpg](data:image/jpeg;base64,...)
#
# 결과
#
# ![KakaoTalk_20260419_223920529.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 7. 6번 문제에서 주어진 이진 검색 트리에서 키 3을 삭제한 후의 모양을 그리시오.
# ![KakaoTalk_20260419_222802961_01.png](data:image/png;base64,...)

# %% [markdown]
# 8. 6번 문제에서 주어진 이진 검색 트리에서 키 15를 삭제한 후의 모양을 그리시오.
#
# 1) 왼쪽 서브트리에서 가장 큰 노드로 대체
# ![KakaoTalk_20260419_223920529.jpg](data:image/jpeg;base64,...)
#
# 2. 오른쪽 서브트리에서 가장 작은 노드로 대체
# ![KakaoTalk_20260419_223552223.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 9. n개의 원소로 구성되는 이진 검색 트리의 가능한 최대 높이와 최소 높이는 어떻게
# 되는가?
#
#
# ```
# 최대 높이: n
# 최소 높이: logn
# ```
